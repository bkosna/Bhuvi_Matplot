# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Visualization Choice: Stacked bar chart
# A stacked bar chart is the best option for visualising the percentages of responses in the Evaluation variable, broken down by non-white and sex categories. This kind of chart makes it easier to compare proportions and makes it clear how various demographic groupings affect the total evaluation replies. Every row of the stacked bars will show the responses' composition, providing information on how different groups understand political evaluations. Understanding the intricacies of public opinion is crucial, and this kind of clarity is in line with my professional goals in political analysis and voter behaviour. Through the preparation of data to align with these percentages, as well as the creation of a chart featuring unambiguous labelling and a legend, I am able to demonstrate how demographic characteristics interact with evaluation outcomes.
# ## Considering
# You can clearly show the connections between evaluation responses and demographic groups by utilising a stacked bar chart. This graphic will improve your analysis and offer insightful information about the movements of public opinion. Once these adjustments have been made, go over the chart to make sure your analytical objectives have been met.

# %%
dep = pd.read_csv('cces_example_data.csv')
dep.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig, axal = plt.subplots(1, 2, figsize=(6, 3))

axal[0].set_title("Age Histogram")
axal[1].set_title("Political Identity")

plt.show()

# %%
evaluation_counts = dep['Evaluation'].value_counts()

plt.figure(figsize=(4, 2.5))
evaluation_counts.plot(kind='bar', color='skyblue')
plt.title('Evaluation Responses')
plt.xlabel('Evaluation Categories')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(4, 2.5))
plt.scatter(dep['ConMediaUse'], dep['ImmiPhobia'], alpha=0.6)
plt.title('Scatter Plot of ConMediaUse vs. ImmiPhobia')
plt.xlabel('ConMediaUse')
plt.ylabel('ImmiPhobia')
plt.grid(True)
plt.show()

# %% [markdown]
# # Enhancing Your Scatter Plot
#
# Here's how to use the techniques you described to improve your ConMediaUse and ImmiPhobia scatter plot in a more organised way:
#
# ### Upgrades to the Scatter Plot
#
# 1. **Colour Coding:** - **Implementation:** Designate various demographic categories (e.g., gender, age groups) using separate colours.
#    **Advantages:** This will make data points visually distinct and make it easier to spot trends or patterns within particular demographic groups.
#
# 2. **Trend Lines:**-**Implementation:** To show how ConMediaUse and ImmiPhobia are related, add regression lines.
#    **Advantages:** Trend lines can indicate whether the variables have a positive, negative, or no association at all, which enlarges the plot's informativeness.
#
# 3. **Installation:** - **Markers:** Data points should have a range of sizes and forms to represent additional categorical variables (e.g., education level, geographic region).
#  **Benefits:** By adding yet another layer of information, viewers are better able to swiftly and easily recognise group differences.
# 4. **Text Expansion:-** **Application:** Modify the point transparency (alpha) to lessen overplotting in the plot's heavily populated regions.
# **Benefits:** By making things more clear, patterns and trends may be highlighted without sacrificing crucial information.
